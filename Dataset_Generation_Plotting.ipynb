# %% [markdown]
# # Query Dataset Generation for the Model
# -----------

# %%
def loads_applied_at_position(position,dataframe):
    fig=plt.figure()
    ax=fig.add_axes([0,0,1,1])
    ax.set_title("DISTANCE FROM FIXED END: {} mm".format(position),fontsize=20,color='r')
    ax.set_ylabel('LOAD INTENSITY in kN',fontsize=15)
    ax.set_xlabel('LOAD MAGNITUDES in kN',fontsize=15)
    ax.xaxis.labelpad=15
    
    ax.yaxis.set_ticklabels([])
    
    uv=upper_values(position)

    y=dataframe['F(x='+str(position)+')'].iloc[uv-10:uv].values
    x=range(10)
    ax.bar(x,-y)

    ax.xaxis.set(ticks=range(0,10),ticklabels=[100,200,300,400,500,600,700,800,
                                          900,1000])

    plt.grid(True,color='g',ls='-.',lw=0.25)
    plt.show()
    
###################
def upper_values(position):
    return int((1200-position)/20)

###############################################################################################

# To plot the loading diagram for any given load value and load position

def plot_loading(load_value,load_position):
    fig=plt.figure()
    ax=fig.add_axes([0,0,1,1])
    ax.set_title('LOADING DIAGRAM',fontsize=20,color='r')
    ax.xaxis.labelpad=10
    ax.set_xticks([0,100,200,300,400,500,600,700,800,900,1000])
    ax.yaxis.set_ticklabels([])
    
    

    ax.plot([x for x in range(0,1100,100)],[0 for x in range(0,1100,100)],'go-')

    ax.annotate('LOAD={} kN'.format(load_value),xy=(load_position,0),xytext=(load_position,0.02)
            ,arrowprops=dict(facecolor='red',shrink=0.01*load_value),fontsize=20)

    ax.annotate('FIXED END',xy=(0,0),xytext=(100,-0.02),
            arrowprops=dict(facecolor='blue',arrowstyle='->'),fontsize=10)
    
    ax.annotate('({},{})'.format(load_position,0),xy=(load_position,0),xytext=(load_position,-0.005)
                ,fontsize=10)

    ax.axis([-50,1050,-0.04,0.04])

    ax.grid(True,color='g',ls='-.',lw=0.25)

    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_color('black')
    
###########################################################################################

# To check all the different combination of loading 
def check_loading(load_values,load_position,dataframe):
    
    i=0  # this variable will iterate over the different sets (5 sets are here; 1000 mm,800 mm,600...200 mm)
    j=0  # this variable will iterate over the values present inside the set (10 values in each set; 100kN,200...1000kN)
    
    check=True
    
    for val in load_values:
        #print("-"*30)
        #print("\tLOAD: {} kN".format(val))
        #print("\t"+"-"*10)
    
    
        for pos in load_position:
        
            position=obtain_position_from_column_name(pos)
            #print("LOAD POSITION: {} mm".format(position))
            
            if -val!=dataframe[pos].iloc[i:i+1].values:
                print("Mismatch of loading and position")
                print("Load: ",val)
                print("Position: ",position)
                check=False
                
            
            i=i+len(load_values)   # len(load_values) is the step taken for iterating over sets by variable 'i'.
            
        #print('\t'+'-'*(len("CHECK PASS")))
        #print("\tCHECK PASS")
        #print('\t'+'-'*len("CHECK PASS"))
        
        j=j+1    # +1 , is the step taken for iterating over the values of the sets.
        i=j      # For bringing back of the set iterator to the initial position (i.e, set zero)
        
    if check==True:
        print("-"*15+"x"+"-"*15)
        print("All Check Passed")
        print("-"*15+"x"+"-"*15)

    
#####################
def obtain_position_from_column_name(column_name):

    k=column_name.split('=')
    k=k[-1].split(')')
    k=int(k[0])
    return k

#####################################################################################

# %% [markdown]
# ----------
# ### STEP 0: Importing dependencies:
# ----------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
excel_file_1='breadth_200.xlsx'

# %%
df_first_shift=pd.read_excel(excel_file_1)

# %%
df_first_shift.iloc[:10]
# Out:
#                                                   #          Unnamed: 1  \
# 0                              # 02/20/2021 15:32:27                NaN
# 1       # The parameters defined in the project are:                NaN
# 2                                                 #   P1 - Breadth [mm]
# 3                                                 #                 NaN
# 4  # The following header line defines the name o...                NaN
# 5                                               Name                 P1
# 6                                               DP 0                200
# 7                                                NaN                200
# 8                                                NaN                200
# 9                                                NaN                200
#
#          Unnamed: 2                               Unnamed: 3  \
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2  P2 - Height [mm]  P4 - Compressive Ultimate Strength [Pa]
# 3               NaN                                      NaN
# 4               NaN                                      NaN
# 5                P2                                       P4
# 6               200                                 41000000
# 7               200                                 41000000
# 8               200                                 41000000
# 9               200                                 41000000
#
#                             Unnamed: 4              Unnamed: 5  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2  P5 - Tensile Ultimate Strength [Pa]  P6 - Density [kg m^-3]
# 3                                  NaN                     NaN
# 4                                  NaN                     NaN
# 5                                   P5                      P6
# 6                              5000000                    2300
# 7                              5000000                    2300
# 8                              5000000                    2300
# 9                              5000000                    2300
#
#                    Unnamed: 6                       Unnamed: 7  \
# 0                         NaN                              NaN
# 1                         NaN                              NaN
# 2  P13 - Young's Modulus [Pa]  P14 - F(x=1000) Y Component [N]
# 3                         NaN                              NaN
# 4                         NaN                              NaN
# 5                         P13                              P14
# 6                 30000000000                             -100
# 7                 30000000000                             -200
# 8                 30000000000                             -300
# 9                 30000000000                             -400
#
#                        Unnamed: 8                      Unnamed: 9  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2  P15 - F(x=800) Y Component [N]  P16 - F(x=600) Y Component [N]
# 3                             NaN                             NaN
# 4                             NaN                             NaN
# 5                             P15                             P16
# 6                           1e-06                           1e-06
# 7                           1e-06                           1e-06
# 8                           1e-06                           1e-06
# 9                           1e-06                           1e-06
#
#                       Unnamed: 10                      Unnamed: 11  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2  P17 - F(x=400) Y Component [N]  P18 - F(x=200)  Y Component [N]
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             P17                              P18
# 6                           1e-06                            1e-06
# 7                           1e-06                            1e-06
# 8                           1e-06                            1e-06
# 9                           1e-06                            1e-06
#
#                              Unnamed: 12
# 0                                    NaN
# 1                                    NaN
# 2  P12 - Equivalent Stress Maximum [MPa]
# 3                                    NaN
# 4                                    NaN
# 5                                    P12
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN

# %% [markdown]
# ----------
# ### STEP 1: Generating $df2$
# ----------
#
# - **df2**, it will contain 50 rows.
# - 5 set of 10 rows.
#
# ---
# - 10 rows of one set defines, 10 different values for a load at a given position.
#     - 100kN,200kN,300kN,...900kN,1000kN, these are 10 values of load which are applied at position x=1000 mm.
#
# ---
# - 5 different sets defines 5 different positions of a beam.
#     - x=1000 mm, x= 800 mm, ... x= 200 mm

# %% [markdown]
# #### Copying relevant data to a new dataframe $df2$ :
# ------

# %%
df2=pd.DataFrame(data=df_first_shift.iloc[6:56].values,
                 columns=['Name', 'P1', 'P2', 'P4', 'P5', 'P6', 
                          'P13', 'P14', 'P15', 'P16','P17', 'P18', 'P12'])

# %%
df2.head(10)
# Out:
#    Name   P1   P2        P4       P5    P6          P13    P14    P15    P16  \
# 0  DP 0  200  200  41000000  5000000  2300  30000000000   -100  1e-06  1e-06
# 1   NaN  200  200  41000000  5000000  2300  30000000000   -200  1e-06  1e-06
# 2   NaN  200  200  41000000  5000000  2300  30000000000   -300  1e-06  1e-06
# 3   NaN  200  200  41000000  5000000  2300  30000000000   -400  1e-06  1e-06
# 4   NaN  200  200  41000000  5000000  2300  30000000000   -500  1e-06  1e-06
# 5   NaN  200  200  41000000  5000000  2300  30000000000   -600  1e-06  1e-06
# 6   NaN  200  200  41000000  5000000  2300  30000000000   -700  1e-06  1e-06
# 7   NaN  200  200  41000000  5000000  2300  30000000000   -800  1e-06  1e-06
# 8   NaN  200  200  41000000  5000000  2300  30000000000   -900  1e-06  1e-06
# 9   NaN  200  200  41000000  5000000  2300  30000000000  -1000  1e-06  1e-06
#
#      P17    P18  P12
# 0  1e-06  1e-06  NaN
# 1  1e-06  1e-06  NaN
# 2  1e-06  1e-06  NaN
# 3  1e-06  1e-06  NaN
# 4  1e-06  1e-06  NaN
# 5  1e-06  1e-06  NaN
# 6  1e-06  1e-06  NaN
# 7  1e-06  1e-06  NaN
# 8  1e-06  1e-06  NaN
# 9  1e-06  1e-06  NaN

# %% [markdown]
# #### Obtaining the column names from the original dataset:
# ------

# %%
df_first_shift.iloc[2:3]
# Out:
#    #          Unnamed: 1        Unnamed: 2  \
# 2  #   P1 - Breadth [mm]  P2 - Height [mm]
#
#                                 Unnamed: 3  \
# 2  P4 - Compressive Ultimate Strength [Pa]
#
#                             Unnamed: 4              Unnamed: 5  \
# 2  P5 - Tensile Ultimate Strength [Pa]  P6 - Density [kg m^-3]
#
#                    Unnamed: 6                       Unnamed: 7  \
# 2  P13 - Young's Modulus [Pa]  P14 - F(x=1000) Y Component [N]
#
#                        Unnamed: 8                      Unnamed: 9  \
# 2  P15 - F(x=800) Y Component [N]  P16 - F(x=600) Y Component [N]
#
#                       Unnamed: 10                      Unnamed: 11  \
# 2  P17 - F(x=400) Y Component [N]  P18 - F(x=200)  Y Component [N]
#
#                              Unnamed: 12
# 2  P12 - Equivalent Stress Maximum [MPa]

# %% [markdown]
# #### Renaming the column names in $df2$:
# -----------

# %%
k=df_first_shift.iloc[2:3].values

k=['# ', 'Breadth [mm]', 'Height [mm]',
        'Compressive Ultimate Strength [Pa]',
        'Tensile Ultimate Strength [Pa]', 'Density [kg m^-3]',
        "Young's Modulus [Pa]", 'F(x=1000)',
        'F(x=800)',
        'F(x=600)',
        'F(x=400)',
        'F(x=200)',
        'Equivalent Stress Maximum [MPa]']

df2=pd.DataFrame(data=df_first_shift.iloc[6:56].values,
                 columns=k)

# %%
df2.columns
# Out:
# Index(['# ', 'Breadth [mm]', 'Height [mm]',
#        'Compressive Ultimate Strength [Pa]', 'Tensile Ultimate Strength [Pa]',
#        'Density [kg m^-3]', 'Young's Modulus [Pa]', 'F(x=1000)', 'F(x=800)',
#        'F(x=600)', 'F(x=400)', 'F(x=200)', 'Equivalent Stress Maximum [MPa]'],
#       dtype='object')

# %%
df2.head()
# Out:
#      #  Breadth [mm] Height [mm] Compressive Ultimate Strength [Pa]  \
# 0  DP 0          200         200                           41000000
# 1   NaN          200         200                           41000000
# 2   NaN          200         200                           41000000
# 3   NaN          200         200                           41000000
# 4   NaN          200         200                           41000000
#
#   Tensile Ultimate Strength [Pa] Density [kg m^-3] Young's Modulus [Pa]  \
# 0                        5000000              2300          30000000000
# 1                        5000000              2300          30000000000
# 2                        5000000              2300          30000000000
# 3                        5000000              2300          30000000000
# 4                        5000000              2300          30000000000
#
#   F(x=1000) F(x=800) F(x=600) F(x=400) F(x=200)  \
# 0      -100    1e-06    1e-06    1e-06    1e-06
# 1      -200    1e-06    1e-06    1e-06    1e-06
# 2      -300    1e-06    1e-06    1e-06    1e-06
# 3      -400    1e-06    1e-06    1e-06    1e-06
# 4      -500    1e-06    1e-06    1e-06    1e-06
#
#   Equivalent Stress Maximum [MPa]
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %% [markdown]
# ----------
# ### STEP 2: Generating $df3$:
# -------
#
# - **df3** is the trimmed version of **df2**.
# - It will contain only the feature columns.
#     - By dropping, extra columns from df2.

# %%
df3=df2[['Breadth [mm]', 'Height [mm]',
       'Compressive Ultimate Strength [Pa]', 'Tensile Ultimate Strength [Pa]',
       'Density [kg m^-3]', "Young's Modulus [Pa]", 'F(x=1000)', 'F(x=800)',
       'F(x=600)', 'F(x=400)', 'F(x=200)']]

# %%
df3.head()
# Out:
#   Breadth [mm] Height [mm] Compressive Ultimate Strength [Pa]  \
# 0          200         200                           41000000
# 1          200         200                           41000000
# 2          200         200                           41000000
# 3          200         200                           41000000
# 4          200         200                           41000000
#
#   Tensile Ultimate Strength [Pa] Density [kg m^-3] Young's Modulus [Pa]  \
# 0                        5000000              2300          30000000000
# 1                        5000000              2300          30000000000
# 2                        5000000              2300          30000000000
# 3                        5000000              2300          30000000000
# 4                        5000000              2300          30000000000
#
#   F(x=1000) F(x=800) F(x=600) F(x=400) F(x=200)
# 0      -100    1e-06    1e-06    1e-06    1e-06
# 1      -200    1e-06    1e-06    1e-06    1e-06
# 2      -300    1e-06    1e-06    1e-06    1e-06
# 3      -400    1e-06    1e-06    1e-06    1e-06
# 4      -500    1e-06    1e-06    1e-06    1e-06

# %%
df3.columns
# Out:
# Index(['Breadth [mm]', 'Height [mm]', 'Compressive Ultimate Strength [Pa]',
#        'Tensile Ultimate Strength [Pa]', 'Density [kg m^-3]',
#        'Young's Modulus [Pa]', 'F(x=1000)', 'F(x=800)', 'F(x=600)', 'F(x=400)',
#        'F(x=200)'],
#       dtype='object')

# %% [markdown]
# ----------
# ### STEP 3: Generating different combinations:
# --------------
# - Breadth is to be varied from $200 mm$ to $500 mm$.
# - Height is to be varied from $200 mm$ to $500 mm$.
# - Grade of concrete is to be varied from $M20$ to $M50$.
# - Density changes from 2500 $kg/m^{3}$ to 2750 $kg/m^{3}$ for different grades.

# %%
B=[x for x in range(200,550,50)]
H=[x for x in range(200,550,50)]
Grade=[x for x in range(20,55,5)]
Density=[2500,2750]

print("Breadth [mm]: ",B,"Height [mm]: ",H,"Grade: ",Grade,"Density: ",Density,sep='\n')
# Out:
# Breadth [mm]:
# [200, 250, 300, 350, 400, 450, 500]
# Height [mm]:
# [200, 250, 300, 350, 400, 450, 500]
# Grade:
# [20, 25, 30, 35, 40, 45, 50]
# Density:
# [2500, 2750]

# %% [markdown]
# ----------
# ### STEP 4: Generating the Dataset for each combination:
# --------------
# - Each dataset generated will contain 50 rows.
# - Each dataset is unique.

# %%
i=0
DATASET=[]
Mpa=1000*1000
for b in B:
    for h in H:
        for g in Grade:
            if g<= 30:
                d=Density[0]
            else:
                d=Density[1]
            print("\t\t\tDATASET [{}]".format(i))
            print("B: ",b,"\tH: ",h,"\tGrade: ",g,"\tDensity: ",d)
            print("."*40)
            print("Compressive Strength: ",g*Mpa)
            print("Tensile Strength: ",int(0.7*np.sqrt(g)*Mpa))
            print("Young's Modulus: ",int(5000*np.sqrt(g)*Mpa))
            print("-"*40)
            df3.loc[:,'Breadth [mm]']=int(b)
            df3.loc[:,'Height [mm]']=int(h)
            df3.loc[:,'Compressive Ultimate Strength [Pa]']=g*Mpa
            df3.loc[:,'Tensile Ultimate Strength [Pa]']=int(0.7*np.sqrt(g)*Mpa)
            df3.loc[:,'Density [kg m^-3]']=d
            df3.loc[:,"Young's Modulus [Pa]"]=int(5000*np.sqrt(g)*Mpa)
           
            df=df3.copy()
            DATASET.append(df)
            
            i=i+1
        
print("Total Combinations: {}".format(i))
# Out:
# 			DATASET [0]
# B:  200 	H:  200 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [1]
# B:  200 	H:  200 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [2]
# B:  200 	H:  200 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [3]
# B:  200 	H:  200 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [4]
# B:  200 	H:  200 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [5]
# B:  200 	H:  200 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [6]
# B:  200 	H:  200 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [7]
# B:  200 	H:  250 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [8]
# B:  200 	H:  250 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [9]
# B:  200 	H:  250 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [10]
# B:  200 	H:  250 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [11]
# B:  200 	H:  250 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [12]
# B:  200 	H:  250 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [13]
# B:  200 	H:  250 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [14]
# B:  200 	H:  300 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [15]
# B:  200 	H:  300 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [16]
# B:  200 	H:  300 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [17]
# B:  200 	H:  300 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [18]
# B:  200 	H:  300 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [19]
# B:  200 	H:  300 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [20]
# B:  200 	H:  300 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [21]
# B:  200 	H:  350 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [22]
# B:  200 	H:  350 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [23]
# B:  200 	H:  350 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [24]
# B:  200 	H:  350 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [25]
# B:  200 	H:  350 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [26]
# B:  200 	H:  350 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [27]
# B:  200 	H:  350 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [28]
# B:  200 	H:  400 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [29]
# B:  200 	H:  400 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [30]
# B:  200 	H:  400 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [31]
# B:  200 	H:  400 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [32]
# B:  200 	H:  400 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [33]
# B:  200 	H:  400 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [34]
# B:  200 	H:  400 	Grade:  50 	Density:  2750
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [35]
# B:  200 	H:  450 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [36]
# B:  200 	H:  450 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [37]
# B:  200 	H:  450 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [38]
# B:  200 	H:  450 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [39]
# B:  200 	H:  450 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [40]
# B:  200 	H:  450 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [41]
# B:  200 	H:  450 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [42]
# B:  200 	H:  500 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [43]
# B:  200 	H:  500 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [44]
# B:  200 	H:  500 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [45]
# B:  200 	H:  500 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [46]
# B:  200 	H:  500 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [47]
# B:  200 	H:  500 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [48]
# B:  200 	H:  500 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [49]
# B:  250 	H:  200 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [50]
# B:  250 	H:  200 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [51]
# B:  250 	H:  200 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [52]
# B:  250 	H:  200 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [53]
# B:  250 	H:  200 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [54]
# B:  250 	H:  200 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [55]
# B:  250 	H:  200 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [56]
# B:  250 	H:  250 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [57]
# B:  250 	H:  250 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [58]
# B:  250 	H:  250 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [59]
# B:  250 	H:  250 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [60]
# B:  250 	H:  250 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [61]
# B:  250 	H:  250 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [62]
# B:  250 	H:  250 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [63]
# B:  250 	H:  300 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [64]
# B:  250 	H:  300 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [65]
# B:  250 	H:  300 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [66]
# B:  250 	H:  300 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [67]
# B:  250 	H:  300 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [68]
# B:  250 	H:  300 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [69]
# B:  250 	H:  300 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [70]
# B:  250 	H:  350 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [71]
# B:  250 	H:  350 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [72]
# B:  250 	H:  350 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [73]
# B:  250 	H:  350 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [74]
# B:  250 	H:  350 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [75]
# B:  250 	H:  350 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [76]
# B:  250 	H:  350 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [77]
# B:  250 	H:  400 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [78]
# B:  250 	H:  400 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [79]
# B:  250 	H:  400 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [80]
# B:  250 	H:  400 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [81]
# B:  250 	H:  400 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [82]
# B:  250 	H:  400 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [83]
# B:  250 	H:  400 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [84]
# B:  250 	H:  450 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [85]
# B:  250 	H:  450 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [86]
# B:  250 	H:  450 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [87]
# B:  250 	H:  450 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [88]
# B:  250 	H:  450 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [89]
# B:  250 	H:  450 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [90]
# B:  250 	H:  450 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [91]
# B:  250 	H:  500 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [92]
# B:  250 	H:  500 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [93]
# B:  250 	H:  500 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [94]
# B:  250 	H:  500 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [95]
# B:  250 	H:  500 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [96]
# B:  250 	H:  500 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [97]
# B:  250 	H:  500 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [98]
# B:  300 	H:  200 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [99]
# B:  300 	H:  200 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [100]
# B:  300 	H:  200 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [101]
# B:  300 	H:  200 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [102]
# B:  300 	H:  200 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [103]
# B:  300 	H:  200 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [104]
# B:  300 	H:  200 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [105]
# B:  300 	H:  250 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [106]
# B:  300 	H:  250 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [107]
# B:  300 	H:  250 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [108]
# B:  300 	H:  250 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [109]
# B:  300 	H:  250 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [110]
# B:  300 	H:  250 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [111]
# B:  300 	H:  250 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [112]
# B:  300 	H:  300 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [113]
# B:  300 	H:  300 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [114]
# B:  300 	H:  300 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [115]
# B:  300 	H:  300 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [116]
# B:  300 	H:  300 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [117]
# B:  300 	H:  300 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [118]
# B:  300 	H:  300 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [119]
# B:  300 	H:  350 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [120]
# B:  300 	H:  350 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [121]
# B:  300 	H:  350 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [122]
# B:  300 	H:  350 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [123]
# B:  300 	H:  350 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [124]
# B:  300 	H:  350 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [125]
# B:  300 	H:  350 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [126]
# B:  300 	H:  400 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [127]
# B:  300 	H:  400 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [128]
# B:  300 	H:  400 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [129]
# B:  300 	H:  400 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [130]
# B:  300 	H:  400 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [131]
# B:  300 	H:  400 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [132]
# B:  300 	H:  400 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [133]
# B:  300 	H:  450 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [134]
# B:  300 	H:  450 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [135]
# B:  300 	H:  450 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [136]
# B:  300 	H:  450 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [137]
# B:  300 	H:  450 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [138]
# B:  300 	H:  450 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [139]
# B:  300 	H:  450 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [140]
# B:  300 	H:  500 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [141]
# B:  300 	H:  500 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [142]
# B:  300 	H:  500 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [143]
# B:  300 	H:  500 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [144]
# B:  300 	H:  500 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [145]
# B:  300 	H:  500 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [146]
# B:  300 	H:  500 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [147]
# B:  350 	H:  200 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [148]
# B:  350 	H:  200 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [149]
# B:  350 	H:  200 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [150]
# B:  350 	H:  200 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [151]
# B:  350 	H:  200 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [152]
# B:  350 	H:  200 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [153]
# B:  350 	H:  200 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [154]
# B:  350 	H:  250 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [155]
# B:  350 	H:  250 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [156]
# B:  350 	H:  250 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [157]
# B:  350 	H:  250 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [158]
# B:  350 	H:  250 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [159]
# B:  350 	H:  250 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [160]
# B:  350 	H:  250 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [161]
# B:  350 	H:  300 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [162]
# B:  350 	H:  300 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [163]
# B:  350 	H:  300 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [164]
# B:  350 	H:  300 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [165]
# B:  350 	H:  300 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [166]
# B:  350 	H:  300 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [167]
# B:  350 	H:  300 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [168]
# B:  350 	H:  350 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [169]
# B:  350 	H:  350 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [170]
# B:  350 	H:  350 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [171]
# B:  350 	H:  350 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [172]
# B:  350 	H:  350 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [173]
# B:  350 	H:  350 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [174]
# B:  350 	H:  350 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [175]
# B:  350 	H:  400 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [176]
# B:  350 	H:  400 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [177]
# B:  350 	H:  400 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [178]
# B:  350 	H:  400 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [179]
# B:  350 	H:  400 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [180]
# B:  350 	H:  400 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [181]
# B:  350 	H:  400 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [182]
# B:  350 	H:  450 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [183]
# B:  350 	H:  450 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [184]
# B:  350 	H:  450 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [185]
# B:  350 	H:  450 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [186]
# B:  350 	H:  450 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [187]
# B:  350 	H:  450 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [188]
# B:  350 	H:  450 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [189]
# B:  350 	H:  500 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [190]
# B:  350 	H:  500 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [191]
# B:  350 	H:  500 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [192]
# B:  350 	H:  500 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [193]
# B:  350 	H:  500 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [194]
# B:  350 	H:  500 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [195]
# B:  350 	H:  500 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [196]
# B:  400 	H:  200 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [197]
# B:  400 	H:  200 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [198]
# B:  400 	H:  200 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [199]
# B:  400 	H:  200 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [200]
# B:  400 	H:  200 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [201]
# B:  400 	H:  200 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [202]
# B:  400 	H:  200 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [203]
# ...
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [275]
# B:  450 	H:  400 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [276]
# B:  450 	H:  400 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [277]
# B:  450 	H:  400 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [278]
# B:  450 	H:  400 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [279]
# B:  450 	H:  400 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [280]
# B:  450 	H:  450 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [281]
# B:  450 	H:  450 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [282]
# B:  450 	H:  450 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [283]
# B:  450 	H:  450 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [284]
# B:  450 	H:  450 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [285]
# B:  450 	H:  450 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [286]
# B:  450 	H:  450 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [287]
# B:  450 	H:  500 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [288]
# B:  450 	H:  500 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [289]
# B:  450 	H:  500 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [290]
# B:  450 	H:  500 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [291]
# B:  450 	H:  500 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [292]
# B:  450 	H:  500 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [293]
# B:  450 	H:  500 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [294]
# B:  500 	H:  200 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [295]
# B:  500 	H:  200 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [296]
# B:  500 	H:  200 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [297]
# B:  500 	H:  200 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [298]
# B:  500 	H:  200 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [299]
# B:  500 	H:  200 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [300]
# B:  500 	H:  200 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [301]
# B:  500 	H:  250 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [302]
# B:  500 	H:  250 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [303]
# B:  500 	H:  250 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [304]
# B:  500 	H:  250 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [305]
# B:  500 	H:  250 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [306]
# B:  500 	H:  250 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [307]
# B:  500 	H:  250 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [308]
# B:  500 	H:  300 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [309]
# B:  500 	H:  300 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [310]
# B:  500 	H:  300 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [311]
# B:  500 	H:  300 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [312]
# B:  500 	H:  300 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [313]
# B:  500 	H:  300 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [314]
# B:  500 	H:  300 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [315]
# B:  500 	H:  350 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [316]
# B:  500 	H:  350 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [317]
# B:  500 	H:  350 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [318]
# B:  500 	H:  350 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [319]
# B:  500 	H:  350 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [320]
# B:  500 	H:  350 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [321]
# B:  500 	H:  350 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [322]
# B:  500 	H:  400 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [323]
# B:  500 	H:  400 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [324]
# B:  500 	H:  400 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [325]
# B:  500 	H:  400 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [326]
# B:  500 	H:  400 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [327]
# B:  500 	H:  400 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [328]
# B:  500 	H:  400 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [329]
# B:  500 	H:  450 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [330]
# B:  500 	H:  450 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [331]
# B:  500 	H:  450 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [332]
# B:  500 	H:  450 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [333]
# B:  500 	H:  450 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [334]
# B:  500 	H:  450 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [335]
# B:  500 	H:  450 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# 			DATASET [336]
# B:  500 	H:  500 	Grade:  20 	Density:  2500
# ........................................
# Compressive Strength:  20000000
# Tensile Strength:  3130495
# Young's Modulus:  22360679774
# ----------------------------------------
# 			DATASET [337]
# B:  500 	H:  500 	Grade:  25 	Density:  2500
# ........................................
# Compressive Strength:  25000000
# Tensile Strength:  3500000
# Young's Modulus:  25000000000
# ----------------------------------------
# 			DATASET [338]
# B:  500 	H:  500 	Grade:  30 	Density:  2500
# ........................................
# Compressive Strength:  30000000
# Tensile Strength:  3834057
# Young's Modulus:  27386127875
# ----------------------------------------
# 			DATASET [339]
# B:  500 	H:  500 	Grade:  35 	Density:  2750
# ........................................
# Compressive Strength:  35000000
# Tensile Strength:  4141255
# Young's Modulus:  29580398915
# ----------------------------------------
# 			DATASET [340]
# B:  500 	H:  500 	Grade:  40 	Density:  2750
# ........................................
# Compressive Strength:  40000000
# Tensile Strength:  4427188
# Young's Modulus:  31622776601
# ----------------------------------------
# 			DATASET [341]
# B:  500 	H:  500 	Grade:  45 	Density:  2750
# ........................................
# Compressive Strength:  45000000
# Tensile Strength:  4695742
# Young's Modulus:  33541019662
# ----------------------------------------
# 			DATASET [342]
# B:  500 	H:  500 	Grade:  50 	Density:  2750
# ........................................
# Compressive Strength:  50000000
# Tensile Strength:  4949747
# Young's Modulus:  35355339059
# ----------------------------------------
# Total Combinations: 343

# %% [markdown]
# ----------
# ### STEP 5: Saving files to the required location:  (Varies)
# --------------

# %%
i=0
Mpa=1000*1000
for b in B:
    for h in H:
        for g in Grade:
            if g<= 30:
                d=Density[0]
            else:
                d=Density[1]
            #print("\t\t\tDATASET [{}]".format(i))
            #print("B: ",b,"\tH: ",h,"\tGrade: ",g,"\tDensity: ",d)
            #print("."*40)
            name='B_'+str(b)+'_H_'+str(h)+'_M'+str(g)+'_Dnty_'+str(d)
            df2=DATASET[i].copy()
            print("File Name: ",name)
            #df2.to_csv("C:\\Users\\abhij\\Downloads\\ANSYS_DATASET\\"+name+".csv")    **!**
            print("Uploaded..!")
            i=i+1
# Out:
# File Name:  B_200_H_200_M20_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_200_M25_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_200_M30_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_200_M35_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_200_M40_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_200_M45_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_200_M50_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_250_M20_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_250_M25_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_250_M30_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_250_M35_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_250_M40_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_250_M45_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_250_M50_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_300_M20_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_300_M25_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_300_M30_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_300_M35_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_300_M40_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_300_M45_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_300_M50_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_350_M20_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_350_M25_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_350_M30_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_350_M35_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_350_M40_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_350_M45_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_350_M50_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_400_M20_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_400_M25_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_400_M30_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_400_M35_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_400_M40_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_400_M45_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_400_M50_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_450_M20_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_450_M25_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_450_M30_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_450_M35_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_450_M40_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_450_M45_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_450_M50_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_500_M20_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_500_M25_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_500_M30_Dnty_2500
# Uploaded..!
# File Name:  B_200_H_500_M35_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_500_M40_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_500_M45_Dnty_2750
# Uploaded..!
# File Name:  B_200_H_500_M50_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_200_M20_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_200_M25_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_200_M30_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_200_M35_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_200_M40_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_200_M45_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_200_M50_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_250_M20_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_250_M25_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_250_M30_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_250_M35_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_250_M40_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_250_M45_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_250_M50_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_300_M20_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_300_M25_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_300_M30_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_300_M35_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_300_M40_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_300_M45_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_300_M50_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_350_M20_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_350_M25_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_350_M30_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_350_M35_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_350_M40_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_350_M45_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_350_M50_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_400_M20_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_400_M25_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_400_M30_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_400_M35_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_400_M40_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_400_M45_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_400_M50_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_450_M20_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_450_M25_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_450_M30_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_450_M35_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_450_M40_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_450_M45_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_450_M50_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_500_M20_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_500_M25_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_500_M30_Dnty_2500
# Uploaded..!
# File Name:  B_250_H_500_M35_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_500_M40_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_500_M45_Dnty_2750
# Uploaded..!
# File Name:  B_250_H_500_M50_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_200_M20_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_200_M25_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_200_M30_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_200_M35_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_200_M40_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_200_M45_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_200_M50_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_250_M20_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_250_M25_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_250_M30_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_250_M35_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_250_M40_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_250_M45_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_250_M50_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_300_M20_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_300_M25_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_300_M30_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_300_M35_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_300_M40_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_300_M45_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_300_M50_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_350_M20_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_350_M25_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_350_M30_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_350_M35_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_350_M40_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_350_M45_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_350_M50_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_400_M20_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_400_M25_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_400_M30_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_400_M35_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_400_M40_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_400_M45_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_400_M50_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_450_M20_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_450_M25_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_450_M30_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_450_M35_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_450_M40_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_450_M45_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_450_M50_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_500_M20_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_500_M25_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_500_M30_Dnty_2500
# Uploaded..!
# File Name:  B_300_H_500_M35_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_500_M40_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_500_M45_Dnty_2750
# Uploaded..!
# File Name:  B_300_H_500_M50_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_200_M20_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_200_M25_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_200_M30_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_200_M35_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_200_M40_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_200_M45_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_200_M50_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_250_M20_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_250_M25_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_250_M30_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_250_M35_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_250_M40_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_250_M45_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_250_M50_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_300_M20_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_300_M25_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_300_M30_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_300_M35_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_300_M40_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_300_M45_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_300_M50_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_350_M20_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_350_M25_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_350_M30_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_350_M35_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_350_M40_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_350_M45_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_350_M50_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_400_M20_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_400_M25_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_400_M30_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_400_M35_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_400_M40_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_400_M45_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_400_M50_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_450_M20_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_450_M25_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_450_M30_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_450_M35_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_450_M40_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_450_M45_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_450_M50_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_500_M20_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_500_M25_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_500_M30_Dnty_2500
# Uploaded..!
# File Name:  B_350_H_500_M35_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_500_M40_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_500_M45_Dnty_2750
# Uploaded..!
# File Name:  B_350_H_500_M50_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_200_M20_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_200_M25_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_200_M30_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_200_M35_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_200_M40_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_200_M45_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_200_M50_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_250_M20_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_250_M25_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_250_M30_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_250_M35_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_250_M40_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_250_M45_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_250_M50_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_300_M20_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_300_M25_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_300_M30_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_300_M35_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_300_M40_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_300_M45_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_300_M50_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_350_M20_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_350_M25_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_350_M30_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_350_M35_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_350_M40_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_350_M45_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_350_M50_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_400_M20_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_400_M25_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_400_M30_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_400_M35_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_400_M40_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_400_M45_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_400_M50_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_450_M20_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_450_M25_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_450_M30_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_450_M35_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_450_M40_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_450_M45_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_450_M50_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_500_M20_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_500_M25_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_500_M30_Dnty_2500
# Uploaded..!
# File Name:  B_400_H_500_M35_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_500_M40_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_500_M45_Dnty_2750
# Uploaded..!
# File Name:  B_400_H_500_M50_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_200_M20_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_200_M25_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_200_M30_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_200_M35_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_200_M40_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_200_M45_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_200_M50_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_250_M20_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_250_M25_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_250_M30_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_250_M35_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_250_M40_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_250_M45_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_250_M50_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_300_M20_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_300_M25_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_300_M30_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_300_M35_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_300_M40_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_300_M45_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_300_M50_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_350_M20_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_350_M25_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_350_M30_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_350_M35_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_350_M40_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_350_M45_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_350_M50_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_400_M20_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_400_M25_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_400_M30_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_400_M35_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_400_M40_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_400_M45_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_400_M50_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_450_M20_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_450_M25_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_450_M30_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_450_M35_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_450_M40_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_450_M45_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_450_M50_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_500_M20_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_500_M25_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_500_M30_Dnty_2500
# Uploaded..!
# File Name:  B_450_H_500_M35_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_500_M40_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_500_M45_Dnty_2750
# Uploaded..!
# File Name:  B_450_H_500_M50_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_200_M20_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_200_M25_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_200_M30_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_200_M35_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_200_M40_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_200_M45_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_200_M50_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_250_M20_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_250_M25_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_250_M30_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_250_M35_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_250_M40_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_250_M45_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_250_M50_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_300_M20_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_300_M25_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_300_M30_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_300_M35_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_300_M40_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_300_M45_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_300_M50_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_350_M20_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_350_M25_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_350_M30_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_350_M35_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_350_M40_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_350_M45_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_350_M50_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_400_M20_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_400_M25_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_400_M30_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_400_M35_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_400_M40_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_400_M45_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_400_M50_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_450_M20_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_450_M25_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_450_M30_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_450_M35_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_450_M40_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_450_M45_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_450_M50_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_500_M20_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_500_M25_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_500_M30_Dnty_2500
# Uploaded..!
# File Name:  B_500_H_500_M35_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_500_M40_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_500_M45_Dnty_2750
# Uploaded..!
# File Name:  B_500_H_500_M50_Dnty_2750
# Uploaded..!

# %%
DATASET[0].head()
# Out:
#    Breadth [mm]  Height [mm]  Compressive Ultimate Strength [Pa]  \
# 0           200          200                            20000000
# 1           200          200                            20000000
# 2           200          200                            20000000
# 3           200          200                            20000000
# 4           200          200                            20000000
#
#    Tensile Ultimate Strength [Pa]  Density [kg m^-3]  Young's Modulus [Pa]  \
# 0                         3130495               2500           22360679774
# 1                         3130495               2500           22360679774
# 2                         3130495               2500           22360679774
# 3                         3130495               2500           22360679774
# 4                         3130495               2500           22360679774
#
#   F(x=1000) F(x=800) F(x=600) F(x=400) F(x=200)
# 0      -100    1e-06    1e-06    1e-06    1e-06
# 1      -200    1e-06    1e-06    1e-06    1e-06
# 2      -300    1e-06    1e-06    1e-06    1e-06
# 3      -400    1e-06    1e-06    1e-06    1e-06
# 4      -500    1e-06    1e-06    1e-06    1e-06

# %%
DATASET[52].head()
# Out:
#    Breadth [mm]  Height [mm]  Compressive Ultimate Strength [Pa]  \
# 0           250          200                            35000000
# 1           250          200                            35000000
# 2           250          200                            35000000
# 3           250          200                            35000000
# 4           250          200                            35000000
#
#    Tensile Ultimate Strength [Pa]  Density [kg m^-3]  Young's Modulus [Pa]  \
# 0                         4141255               2750           29580398915
# 1                         4141255               2750           29580398915
# 2                         4141255               2750           29580398915
# 3                         4141255               2750           29580398915
# 4                         4141255               2750           29580398915
#
#   F(x=1000) F(x=800) F(x=600) F(x=400) F(x=200)
# 0      -100    1e-06    1e-06    1e-06    1e-06
# 1      -200    1e-06    1e-06    1e-06    1e-06
# 2      -300    1e-06    1e-06    1e-06    1e-06
# 3      -400    1e-06    1e-06    1e-06    1e-06
# 4      -500    1e-06    1e-06    1e-06    1e-06

# %% [markdown]
# -----------

# %% [markdown]
# ### Helping Functions:
# ------------------

# %% [markdown]
# **1. plot_loading(load_value, load_position):**
# - When we call this function, it will plot the loading diagram for a given problem.
#
# - This function will help us to know that whether we have applied the load at correct position or not.

# %%
plot_loading(load_value=1000,load_position=400)

# %% [markdown]
# -------
# **2. loads_applied_at_position(position, dataframe):**
#
# - This function plots all the different intensity of loads applied at a given position.
#
# - As for a given dataset (50 rows), load varies from 100kN to 1000kN, therefore at any given position 'x' all the loads must be applied there atleast once.
#     - 50 rows = 10 load_values * 5 load_positions
#
# - Therefore, this function shows the intensity of those load values and let's us cross check the process.

# %%
loads_applied_at_position(position=400,dataframe=DATASET[324])

# %% [markdown]
# -----------
# **3. check_loading(load_values,load_position,dataframe):**
#
# - This function is a testing function, it checks whether a particular load has been applied to all the positions or not.
#     - Ex: It will check whether 100kN has been applied to all the different positions (1000 mm, 800 mm, 600 mm...200 mm) or not. And then again same process is repeated but this time load value becomes 200kN. The process is repeated until the last specified value of the load.

# %%
check_loading(load_values=[x for x in range(100,1100,100)],
             load_position=list(DATASET[6].columns)[-5:],
              dataframe=DATASET[6])
# Out:
# ---------------x---------------
# All Check Passed
# ---------------x---------------

# %% [markdown]
# ----------
# ----------------------
# ## -----------------x-----------------Thank You------------------x------------------
# -----------
# ------------
